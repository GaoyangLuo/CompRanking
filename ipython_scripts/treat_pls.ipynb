# %%
import pandas as pd

# %%
input_plsf="/lomi_home/gaoyang/software/CompRanking/tmp_singa/singa/CompRanking_intermediate/MGE/Plasflow/SRR5997545_5M.contigs_plasflow_prediction_final.tsv"
input_index="/lomi_home/gaoyang/software/CompRanking/tmp_singa/singa/CompRanking_intermediate/MGE/Plasflow/SRR5997545_5M.contigs_Contig_translation.tsv"
df_index=pd.read_csv(input_index,header=None,sep="\t")

df_plsf=pd.read_csv(input_plsf,header=0,sep="\t")
for i, name in df_plsf.iterrows():
    df_plsf["contig_name"][i]=str(df_plsf["contig_name"][i]).lstrip("0")
    print(type(name["contig_name"]))

df_plsf
# Out:
# /tmp/ipykernel_332722/1220465190.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_plsf["contig_name"][i]=str(df_plsf["contig_name"][i]).lstrip("0")
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
df_index
# Out:
#              0             1
# 0            1       >k119_7
# 1            2       >k119_8
# 2            3      >k119_12
# 3            4      >k119_14
# 4            5      >k119_15
# ...        ...           ...
# 123141  123142  >k119_301771
# 123142  123143  >k119_301773
# 123143  123144  >k119_301779
# 123144  123145  >k119_301780
# 123145  123146  >k119_301781
#
# [123146 rows x 2 columns]

# %%
index_dic={}
for i, name in df_index.iterrows():
    index_dic.setdefault(str(name[0]),str(name[1].strip(">")))
index_dic
# Out:
# {'1': 'k141_28',
#  '2': 'k141_29',
#  '3': 'k141_42',
#  '4': 'k141_51',
#  '5': 'k141_61',
#  '6': 'k141_69',
#  '7': 'k141_72',
#  '8': 'k141_84',
#  '9': 'k141_90',
#  '10': 'k141_116',
#  '11': 'k141_124',
#  '12': 'k141_138',
#  '13': 'k141_142',
#  '14': 'k141_156',
#  '15': 'k141_169',
#  '16': 'k141_172',
#  '17': 'k141_196',
#  '18': 'k141_197',
#  '19': 'k141_208',
#  '20': 'k141_221',
#  '21': 'k141_236',
#  '22': 'k141_243',
#  '23': 'k141_267',
#  '24': 'k141_282',
#  '25': 'k141_290',
#  '26': 'k141_298',
#  '27': 'k141_301',
#  '28': 'k141_313',
#  '29': 'k141_329',
#  '30': 'k141_333',
#  '31': 'k141_334',
#  '32': 'k141_337',
#  '33': 'k141_343',
#  '34': 'k141_348',
#  '35': 'k141_352',
#  '36': 'k141_361',
#  '37': 'k141_365',
#  '38': 'k141_366',
#  '39': 'k141_370',
#  '40': 'k141_380',
#  '41': 'k141_386',
#  '42': 'k141_390',
#  '43': 'k141_391',
#  '44': 'k141_398',
#  '45': 'k141_405',
#  '46': 'k141_410',
#  '47': 'k141_426',
#  '48': 'k141_444',
# ...

# %%
df_plsf=df_plsf.sort_values("contig_name")
df_plsf
# df_plsf[df_plsf.contig_name == "contig_name"]
# Out:
#      contig_name                      label
# 1255       10012  chromosome.Proteobacteria
# 1256       10019       plasmid.unclassified
# 1257       10021     plasmid.Proteobacteria
# 1258       10022  unclassified.unclassified
# 1259       10025         plasmid.Firmicutes
# ...          ...                        ...
# 1251        9968  unclassified.unclassified
# 1252        9977    chromosome.unclassified
# 106          998  unclassified.unclassified
# 1253        9984       plasmid.unclassified
# 1254        9991         plasmid.Firmicutes
#
# [8616 rows x 2 columns]

# %%
tmp1=df_plsf.drop_duplicates().sort_values("contig_name")
cleanTable=tmp1
if len(cleanTable[cleanTable.contig_name == "contig_name"]) == 0:
    pass
else:
    # cleanTable=tmp1.drop(df.index[7])
    cleanTable=cleanTable[:-1]
cleanTable
# Out:
#      contig_name                      label
# 1255       10012  chromosome.Proteobacteria
# 1256       10019       plasmid.unclassified
# 1257       10021     plasmid.Proteobacteria
# 1258       10022  unclassified.unclassified
# 1259       10025         plasmid.Firmicutes
# ...          ...                        ...
# 1251        9968  unclassified.unclassified
# 1252        9977    chromosome.unclassified
# 106          998  unclassified.unclassified
# 1253        9984       plasmid.unclassified
# 1254        9991         plasmid.Firmicutes
#
# [8616 rows x 2 columns]

# %%
empty=[]
for i ,name in cleanTable.iterrows():
    empty.append(index_dic[name["contig_name"]]) 
cleanTable["contig_name"]=empty
# for i ,name in df_dvf1.iterrows():
#     if name["name"]=="name":
#         df_dvf1.drop([i])
# df_dvf1
cleanTable
# Out:
#      contig_name                      label
# 1255  k141_76566  chromosome.Proteobacteria
# 1256  k141_76614       plasmid.unclassified
# 1257  k141_76620     plasmid.Proteobacteria
# 1258  k141_76621  unclassified.unclassified
# 1259  k141_76636         plasmid.Firmicutes
# ...          ...                        ...
# 1251  k141_76311  unclassified.unclassified
# 1252  k141_76343    chromosome.unclassified
# 106    k141_7657  unclassified.unclassified
# 1253  k141_76388       plasmid.unclassified
# 1254  k141_76426         plasmid.Firmicutes
#
# [8616 rows x 2 columns]

# %%
cleanTable[cleanTable.contig_name == "contig_name"]
# Out:
# Empty DataFrame
# Columns: [contig_name, label]
# Index: []
